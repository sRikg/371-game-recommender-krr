# %%
import json
from urllib.request import urlopen
import requests,json,os,sys,time,re
import pandas as pd
import numpy as np

# %%
req=requests.get('http://steamspy.com/api.php?request=all&page=1')
req.content
# Out:
# b'{"9350":{"appid":9350,"name":"Supreme Commander","developer":"Gas Powered Games","publisher":"Square Enix","score_rank":"","positive":1936,"negative":242,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":386,"average_2weeks":0,"median_forever":251,"median_2weeks":0,"price":"1299","initialprice":"1299","discount":"0","ccu":71},\n"383120":{"appid":383120,"name":"Empyrion - Galactic Survival","developer":"Eleon Game Studios","publisher":"Eleon Game Studios","score_rank":"","positive":21628,"negative":5069,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":3683,"average_2weeks":65,"median_forever":1106,"median_2weeks":65,"price":"1999","initialprice":"1999","discount":"0","ccu":1939},\n"517630":{"appid":517630,"name":"Just Cause 4 Reloaded","developer":"Avalanche Studios","publisher":"Square Enix","score_rank":"","positive":13509,"negative":8740,"userscore":0,"owners":"500,000 .. 1,000,000","average_forever":1233,"average_2weeks":16,"median_forever":851,"medi
# ...

# %%
dic_part = req.json()   ##############  To make requests.models.Response become dict   ###############
dic_part
# Out:
# {'9350': {'appid': 9350,
#   'average_2weeks': 0,
#   'average_forever': 386,
#   'ccu': 71,
#   'developer': 'Gas Powered Games',
#   'discount': '0',
#   'initialprice': '1299',
#   'median_2weeks': 0,
#   'median_forever': 251,
#   'name': 'Supreme Commander',
#   'negative': 242,
#   'owners': '500,000 .. 1,000,000',
#   'positive': 1936,
#   'price': '1299',
#   'publisher': 'Square Enix',
#   'score_rank': '',
#   'userscore': 0},
#  '383120': {'appid': 383120,
#   'average_2weeks': 65,
#   'average_forever': 3683,
#   'ccu': 1939,
#   'developer': 'Eleon Game Studios',
#   'discount': '0',
#   'initialprice': '1999',
#   'median_2weeks': 65,
#   'median_forever': 1106,
#   'name': 'Empyrion - Galactic Survival',
#   'negative': 5069,
#   'owners': '500,000 .. 1,000,000',
#   'positive': 21628,
#   'price': '1999',
#   'publisher': 'Eleon Game Studios',
#   'score_rank': '',
#   'userscore': 0},
#  '517630': {'appid': 517630,
#   'average_2weeks': 16,
# ...

# %%
len(dic_part)
# Out:
# 1000
